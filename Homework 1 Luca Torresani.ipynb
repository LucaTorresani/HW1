# %% [markdown]
# # All the President's Moods
#
# During his tenure as US President, Donald Trump maintained a steady presence on Twitter. Since the words of the politicians tend to affect the behavior of other people, including markets, there is a sizable literature quantifying the effect of politician speeches on market behavior in the aggregate.
#
# Unllke other politicians, Trump's tweets were both impassioned and plentiful. This means Twitter can give a large volume of reactions to work with that have a distribution of "sentiment."
#
# In this assignment:
# 1. (2 points) Load a json file of all the president's tweets from August 30 to November 5th. After loading them, put the following information into a dataframe:
#     - The full text of the Tweet. (string)
#     - Any users mentioned in the Tweet. (string)
#     - The timestamp. (datetime)
#     - The date (YYYY-MM-DD) of the Tweet. (date)
#     - Retweets (numeric)
#     - Favorites (numeric)
#     - Whether the Tweet was censored, meaning zero retweets (binary/boolean).
#
#    __Hint: list comprehensions can be your best friend!__
#
# 2. (2 points) Create a "clean_text" column by doing the following to "full_text":
#     - removing links, which are strings that start with "http"
#     - removing hashtags, which are strings that start with "#"
#     - removing mentions, which are strings that start with "@"
#     - converting text to lower case.
#     - removing punctuation.
#
#    Now report:
#     - The top 10 most common words (omitting stop words).
#     - The top 5 Twitter accounts that are mentioned.
#     - The top 5 most liked ("favorited") tweets.
#     - The top 5 hashtags (hint: use a regular expression).
# 3. (4 points) Graph the daily volme of tweets over time, while annotating any major events.
# 4. (6 points) Run the tweets through sentiment analysis, and report:
#     - The 20 most "negative" and "positive" words.
#     - A graph of the sentiment over time.
#
# 5. (6 points) Trump and the Stock Market
#     - Read in the time series dataset of S&P 500 closing, daily prices. Then merge this data to Trump's daily sentiment scores. __Graph both of them (EXTRA CREDIT GRAPH)__, calculate their correlation, and interpret what you see.
#
#     - Since Trump often comments on the stock market but the stock market may also react to his tweets, it is not clear how the causal relationship should work. Describe in detail how you would answer the question: "Did President Trump's tweet sentiment influence the stock market?" Specifically describe:
#         - The data you would need in addition to these data sources.
#         - The way you would read in the data and manipulate it.
#         - The sort of analysis or statistics you would calculate to answer the question.

# %% [markdown]
# # Homework 1: Luca Torresani
# ## All the President's Moods

# %%
import pandas as pd
import json 
import matplotlib.pyplot as plt
import matplotlib
import re
import string
from nltk.corpus import stopwords
import regex
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
dir_= "/c/Users/Utente/Desktop/homework1_ace592/homework_1_LucaT/Trump_tweets.json"

# %%
with open ('Trump_tweets.json') as file:
    data= json.load(file)

# %%
len (data)
# Out:
# 3018

# %%
type(data)
# Out:
# list

# %%
data [2] ['entities']
# Out:
# {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}

# %%
df = pd.DataFrame()
df['full_text'] = [x['full_text'] for x in data]
name = [x['entities'] ['user_mentions']for x in data]

# %%
name
# Out:
# [[{'screen_name': 'BreitbartNews',
#    'name': 'Breitbart News',
#    'id': 457984599,
#    'id_str': '457984599',
#    'indices': [126, 140]}],
#  [],
#  [],
#  [{'screen_name': 'BreitbartNews',
#    'name': 'Breitbart News',
#    'id': 457984599,
#    'id_str': '457984599',
#    'indices': [98, 112]}],
#  [{'screen_name': 'BreitbartNews',
#    'name': 'Breitbart News',
#    'id': 457984599,
#    'id_str': '457984599',
#    'indices': [82, 96]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'screen_name': 'FoxNews',
#    'name': 'Fox News',
#    'id': 1367531,
#    'id_str': '1367531',
#    'indices': [17, 25]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'screen_name': 'BreitbartNews',
#    'name': 'Breitbart News',
#    'id': 457984599,
#    'id_str': '457984599',
#    'indices': [104, 118]},
#   {'screen_name': 'FBI',
#    'name': 'FBI',
#    'id': 17629860,
#    'id_str': '17629860',
#    'indices': [199, 203]}],
#  [{'screen_name': 'BreitbartNews',
#    'name': 'Breitbart News',
#    'id': 457984599,
#    'id_str': '457984599',
#    'indices': [128, 142]}],
#  [{'screen_name': 'BreitbartNews',
#    'name': 'Breitbart News',
#    'id': 457984599,
#    'id_str': '457984599',
#    'indices': [83, 97]}],
#  [{'screen_name': 'Facebook',
#    'name': 'Facebook',
#    'id': 2425151,
#    'id_str': '2425151',
#    'indices': [28, 37]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'screen_name': 'Facebook',
#    'name': 'Facebook',
#    'id': 2425151,
#    'id_str': '2425151',
#    'indices': [1, 10]}],
#  [],
#  [],
#  [],
#  [],
#  [{'screen_name': 'BreitbartNews',
#    'name': 'Breitbart News',
#    'id': 457984599,
#    'id_str': '457984599',
#    'indices': [118, 132]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'screen_name': 'albertmohler',
#    'name': 'Albert Mohler',
#    'id': 14869587,
#    'id_str': '14869587',
#    'indices': [10, 23]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'screen_name': 'RJHarrisWHP580',
#    'name': 'RJ Harris',
#    'id': 138490752,
#    'id_str': '138490752',
#    'indices': [27, 42]},
#   {'screen_name': 'FoxNews',
#    'name': 'Fox News',
#    'id': 1367531,
#    'id_str': '1367531',
#    'indices': [65, 73]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'screen_name': 'Victoria_Spartz',
#    'name': 'Victoria Spartz',
#    'id': 1205364420,
#    'id_str': '1205364420',
#    'indices': [1, 17]}],
#  [{'screen_name': 'esther4congress',
#    'name': 'Esther Joy King',
#    'id': 1163566564983148544,
#    'id_str': '1163566564983148544',
#    'indices': [25, 41]}],
#  [{'screen_name': 'JakeLaTurner',
#    'name': 'Jake LaTurner',
#    'id': 1082329240681492481,
#    'id_str': '1082329240681492481',
#    'indices': [1, 14]}],
#  [{'screen_name': 'SteveNegronNH',
#    'name': 'Steve Negron',
#    'id': 741426350280585216,
#    'id_str': '741426350280585216',
#    'indices': [14, 28]}],
#  [{'screen_name': 'FrankPallottaNJ',
#    'name': 'Frank Pallotta',
#    'id': 1111986921033605120,
#    'id_str': '1111986921033605120',
#    'indices': [1, 17]}],
#  [{'screen_name': 'CheleFarley',
#    'name': 'Chele Farley',
#    'id': 958786718513160192,
#    'id_str': '958786718513160192',
#    'indices': [1, 13]}],
#  [{'screen_name': 'CliffBentz',
#    'name': 'Cliff Bentz',
#    'id': 1216104257989963776,
#    'id_str': '1216104257989963776',
#    'indices': [1, 12]}],
#  [{'screen_name': 'SheriffTNehls',
#    'name': 'Sheriff Troy Nehls',
#    'id': 3299995136,
#    'id_str': '3299995136',
#    'indices': [20, 34]}],
#  [{'screen_name': 'gcforcongress',
#    'name': 'Genevieve Collins for Congress',
#    'id': 1151905199839223808,
#    'id_str': '1151905199839223808',
#    'indices': [27, 41]}],
#  [{'screen_name': 'JimJusticeWV',
#    'name': 'Governor Jim Justice',
#    'id': 3167789983,
#    'id_str': '3167789983',
#    'indices': [17, 30]}],
#  [{'screen_name': 'derrickvanorden',
#    'name': 'Derrick Van Orden',
#    'id': 2580992246,
#    'id_str': '2580992246',
#    'indices': [1, 17]}],
#  [{'screen_name': 'ElectBlakeMoore',
#    'name': 'Blake Moore',
#    'id': 551935844,
#    'id_str': '551935844',
#    'indices': [13, 29]}],
#  [{'screen_name': 'millermeeks',
#    'name': 'Dr. Miller-Meeks',
#    'id': 18131106,
#    'id_str': '18131106',
#    'indices': [30, 42]}],
#  [{'screen_name': 'ScottFranklinFL',
#    'name': 'Scott Franklin',
#    'id': 1247958910025203712,
#    'id_str': '1247958910025203712',
#    'indices': [16, 32]}],
#  [{'screen_name': 'LisaForCongress',
#    'name': 'Lisa McClain for Congress',
#    'id': 1187551973173796866,
#    'id_str': '1187551973173796866',
#    'indices': [14, 30]}],
#  [{'screen_name': 'jdanbishop',
#    'name': 'Congressman Dan Bishop',
#    'id': 1912799826,
#    'id_str': '1912799826',
#    'indices': [13, 24]}],
#  [{'screen_name': 'NancyMace',
#    'name': 'Nancy Mace',
#    'id': 914815520842616834,
#    'id_str': '914815520842616834',
#    'indices': [9, 19]}],
#  [{'screen_name': 'JimONeillNC',
#    'name': "Jim O'Neill",
#    'id': 1040608812057735168,
#    'id_str': '1040608812057735168',
#    'indices': [13, 25]}],
#  [],
#  [],
#  [],
#  [],
#  [{'screen_name': 'nytimes',
#    'name': 'The New York Times',
#    'id': 807095,
#    'id_str': '807095',
#    'indices': [143, 151]}],
#  [{'screen_name': 'ffweekend',
#    'name': 'FOX&friends Weekend',
#    'id': 272395158,
#    'id_str': '272395158',
#    'indices': [150, 160]}],
#  [],
#  [{'screen_name': 'OANN',
#    'name': 'One America News',
#    'id': 1209936918,
#    'id_str': '1209936918',
#    'indices': [152, 157]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'screen_name': 'FoxNews',
#    'name': 'Fox News',
#    'id': 1367531,
#    'id_str': '1367531',
#    'indices': [66, 74]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'screen_name': 'nytimes',
#    'name': 'The New York Times',
#    'id': 807095,
#    'id_str': '807095',
#    'indices': [4, 12]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'screen_name': 'BreitbartNews',
#    'name': 'Breitbart News',
#    'id': 457984599,
#    'id_str': '457984599',
#    'indices': [107, 121]}],
#  [{'screen_name': 'BreitbartNews',
#    'name': 'Breitbart News',
#    'id': 457984599,
#    'id_str': '457984599',
#    'indices': [96, 110]}],
#  [{'screen_name': 'BreitbartNews',
#    'name': 'Breitbart News',
#    'id': 457984599,
#    'id_str': '457984599',
#    'indices': [83, 97]}],
#  [{'screen_name': 'BreitbartNews',
#    'name': 'Breitbart News',
#    'id': 457984599,
#    'id_str': '457984599',
#    'indices': [95, 109]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'screen_name': 'JoeNBC',
#    'name': 'Joe Scarborough',
#    'id': 21619519,
#    'id_str': '21619519',
#    'indices': [30, 37]}],
#  [],
#  [],
#  [{'screen_name': 'Google',
#    'name': 'Google',
#    'id': 20536157,
#    'id_str': '20536157',
#    'indices': [38, 45]}],
#  [{'screen_name': 'nytimes',
#    'name': 'The New York Times',
#    'id': 807095,
#    'id_str': '807095',
#    'indices': [65, 73]},
#   {'screen_name': 'CNN',
#    'name': 'CNN',
#    'id': 759251,
#    'id_str': '759251',
#    'indices': [224, 228]},
#   {'screen_name': 'andersoncooper',
#    'name': 'Anderson Cooper',
#    'id': 15224867,
#    'id_str': '15224867',
#    'indices': [238, 253]}],
#  [],
#  [],
#  [],
#  [],
#  [{'screen_name': 'foxandfriends',
#    'name': 'FOX & friends',
#    'id': 15513604,
#    'id_str': '15513604',
#    'indices': [77, 91]}],
#  [],
#  [],
#  [],
#  [{'screen_name': 'DonnaShalala',
#    'name': 'Donna E. Shalala',
#    'id': 737719829579345920,
#    'id_str': '737719829579345920',
#    'indices': [123, 136]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'screen_name': 'nytimes',
#    'name': 'The New York Times',
#    'id': 807095,
#    'id_str': '807095',
#    'indices': [107, 115]},
#   {'screen_name': 'Google',
#    'name': 'Google',
#    'id': 20536157,
#    'id_str': '20536157',
#    'indices': [186, 193]},
#   {'screen_name': 'CNN',
#    'name': 'CNN',
#    'id': 759251,
#    'id_str': '759251',
#    'indices': [219, 223]}],
#  [{'screen_name': 'RSBNetwork',
#    'name': 'RSBN 🇺🇸',
#    'id': 4041824789,
#    'id_str': '4041824789',
#    'indices': [10, 21]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'screen_name': 'TuckerCarlson',
#    'name': 'Tucker Carlson',
#    'id': 22703645,
#    'id_str': '22703645',
#    'indices': [114, 128]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'screen_name': 'FoxNews',
#    'name': 'Fox News',
#    'id': 1367531,
#    'id_str': '1367531',
#    'indices': [4, 12]}],
#  [],
#  [],
#  [],
#  [{'screen_name': 'FoxNews',
#    'name': 'Fox News',
#    'id': 1367531,
#    'id_str': '1367531',
#    'indices': [47, 55]}],
#  [],
#  [{'screen_name': 'MSNBC',
#    'name': 'MSNBC',
#    'id': 2836421,
#    'id_str': '2836421',
#    'indices': [73, 79]}],
#  [{'screen_name': 'WashTimes',
#    'name': 'The Washington Times',
#    'id': 14662354,
#    'id_str': '14662354',
#    'indices': [33, 43]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'screen_name': 'TheJusticeDept',
#    'name': 'Justice Department',
#    'id': 73181712,
#    'id_str': '73181712',
#    'indices': [1, 16]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'screen_name': 'OANN',
#    'name': 'One America News',
#    'id': 1209936918,
#    'id_str': '1209936918',
#    'indices': [133, 138]}],
#  [],
#  [{'screen_name': '60Minutes',
#    'name': '60 Minutes',
#    'id': 18812572,
#    'id_str': '18812572',
#    'indices': [58, 68]}],
#  [],
#  [],
#  [],
#  [{'screen_name': 'SecPompeo',
#    'name': 'Secretary Pompeo',
#    'id': 988573326376427520,
#    'id_str': '988573326376427520',
#    'indices': [207, 217]},
#   {'screen_name': 'WHNSC',
#    'name': 'NSC',
#    'id': 840236394865930240,
#    'id_str': '840236394865930240',
#    'indices': [243, 249]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'screen_name': 'SenRonJohnson',
#    'name': 'Senator Ron Johnson',
#    'id': 233737858,
#    'id_str': '233737858',
#    'indices': [19, 33]}],
#  [],
#  [{'screen_name': 'SeanParnellUSA',
#    'name': 'Sean Parnell',
#    'id': 701825647,
#    'id_str': '701825647',
#    'indices': [121, 136]},
#   {'screen_name': 'TheJusticeDept',
#    'name': 'Justice Department',
#    'id': 73181712,
#    'id_str': '73181712',
#    'indices': [264, 279]}],
#  [],
#  [{'screen_name': 'SeanParnellUSA',
#    'name': 'Sean Parnell',
#    'id': 701825647,
#    'id_str': '701825647',
#    'indices': [1, 16]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'screen_name': 'JesseBWatters',
#    'name': 'Jesse Watters',
#    'id': 56561449,
#    'id_str': '56561449',
#    'indices': [23, 37]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'screen_name': 'BreitbartNews',
#    'name': 'Breitbart News',
#    'id': 457984599,
#    'id_str': '457984599',
#    'indices': [92, 106]}],
#  [{'screen_name': 'BreitbartNews',
#    'name': 'Breitbart News',
#    'id': 457984599,
#    'id_str': '457984599',
#    'indices': [94, 108]}],
#  [{'screen_name': 'BreitbartNews',
#    'name': 'Breitbart News',
#    'id': 457984599,
#    'id_str': '457984599',
#    'indices': [120, 134]}],
#  [{'screen_name': 'BreitbartNews',
#    'name': 'Breitbart News',
#    'id': 457984599,
#    'id_str': '457984599',
#    'indices': [98, 112]}],
#  [],
#  [{'screen_name': 'BreitbartNews',
#    'name': 'Breitbart News',
#    'id': 457984599,
#    'id_str': '457984599',
#    'indices': [99, 113]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'screen_name': 'BreitbartNews',
#    'name': 'Breitbart News',
#    'id': 457984599,
#    'id_str': '457984599',
#    'indices': [99, 113]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'screen_name': 'JoeBiden',
#    'name': 'Joe Biden',
#    'id': 939091,
#    'id_str': '939091',
#    'indices': [12, 21]}],
#  [],
#  [],
#  [],
#  [{'screen_name': 'nypost',
#    'name': 'New York Post',
#    'id': 17469289,
#    'id_str': '17469289',
#    'indices': [13, 20]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'screen_name': 'FoxNews',
#    'name': 'Fox News',
#    'id': 1367531,
#    'id_str': '1367531',
#    'indices': [1, 9]}],
#  [],
#  [],
#  [{'screen_name': '60Minutes',
#    'name': '60 Minutes',
#    'id': 18812572,
#    'id_str': '18812572',
#    'indices': [145, 155]}],
#  [],
#  [],
#  [{'screen_name': 'BreitbartNews',
#    'name': 'Breitbart News',
#    'id': 457984599,
#    'id_str': '457984599',
#    'indices': [124, 138]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'screen_name': 'BreitbartNews',
#    'name': 'Breitbart News',
#    'id': 457984599,
#    'id_str': '457984599',
#    'indices': [146, 160]}],
#  [{'screen_name': 'BreitbartNews',
#    'name': 'Breitbart News',
#    'id': 457984599,
#    'id_str': '457984599',
#    'indices': [89, 103]}],
#  [{'screen_name': 'BreitbartNews',
#    'name': 'Breitbart News',
#    'id': 457984599,
#    'id_str': '457984599',
#    'indices': [117, 131]}],
#  [{'screen_name': 'BreitbartNews',
#    'name': 'Breitbart News',
#    'id': 457984599,
#    'id_str': '457984599',
#    'indices': [110, 124]}],
#  [],
#  [],
#  [],
#  [{'screen_name': 'FischbachMN7',
#    'name': 'Michelle Fischbach',
#    'id': 1159929043816460288,
#    'id_str': '1159929043816460288',
#    'indices': [20, 33]}],
#  [{'screen_name': 'JimOberweis',
#    'name': 'Jim Oberweis',
#    'id': 388247614,
#    'id_str': '388247614',
#    'indices': [1, 13]}],
#  [{'screen_name': 'EsshakiCongress',
#    'name': 'Eric Esshaki for Congress',
#    'id': 1188982152551190528,
#    'id_str': '1188982152551190528',
#    'indices': [14, 30]}],
#  [{'screen_name': 'VotePaulJunge',
#    'name': 'Paul Junge',
#    'id': 1194792199004868610,
#    'id_str': '1194792199004868610',
#    'indices': [12, 26]}],
#  [{'screen_name': 'VoteJimMarchant',
#    'name': 'Jim Marchant',
#    'id': 3875206998,
#    'id_str': '3875206998',
#    'indices': [14, 30]}],
#  [{'screen_name': 'DanRodimer',
#    'name': 'Big Dan Rodimer for Congress NV-03',
#    'id': 1163544478688456704,
#    'id_str': '1163544478688456704',
#    'indices': [1, 12]}],
#  [{'screen_name': 'EliseStefanik',
#    'name': 'Elise Stefanik',
#    'id': 109579534,
#    'id_str': '109579534',
#    'indices': [14, 28]}],
#  [{'screen_name': 'BryanSteil',
#    'name': 'Bryan Steil',
#    'id': 986423555025002497,
#    'id_str': '986423555025002497',
#    'indices': [12, 23]}],
#  [{'screen_name': 'ElectLaHood',
#    'name': 'Darin LaHood',
#    'id': 3107996233,
#    'id_str': '3107996233',
#    'indices': [26, 38]}],
#  [{'screen_name': 'BuckForColorado',
#    'name': 'Ken Buck',
#    'id': 34959770,
#    'id_str': '34959770',
#    'indices': [22, 38]}],
#  [{'screen_name': 'cindyhydesmith',
#    'name': 'Cindy Hyde-Smith',
#    'id': 262192574,
#    'id_str': '262192574',
#    'indices': [8, 23]}],
#  [],
#  [],
#  [],
#  [{'screen_name': '60Minutes',
#    'name': '60 Minutes',
#    'id': 18812572,
#    'id_str': '18812572',
#    'indices': [42, 52]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'screen_name': 'BreitbartNews',
#    'name': 'Breitbart News',
#    'id': 457984599,
#    'id_str': '457984599',
#    'indices': [110, 124]}],
#  [{'screen_name': 'BreitbartNews',
#    'name': 'Breitbart News',
#    'id': 457984599,
#    'id_str': '457984599',
#    'indices': [107, 121]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'screen_name': 'SteveKalayjian',
#    'name': 'Stephen',
#    'id': 938470343508942849,
#    'id_str': '938470343508942849',
#    'indices': [143, 158]},
#   {'screen_name': 'Varneyco',
#    'name': 'Varney & Co.',
#    'id': 281610530,
#    'id_str': '281610530',
#    'indices': [159, 168]}],
#  [],
#  [{'screen_name': 'foxandfriends',
#    'name': 'FOX & friends',
#    'id': 15513604,
#    'id_str': '15513604',
#    'indices': [23, 37]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'screen_name': '60Minutes',
#    'name': '60 Minutes',
#    'id': 18812572,
#    'id_str': '18812572',
#    'indices': [88, 98]}],
#  [],
#  [],
#  [],
#  [{'screen_name': 'maggieNYT',
#    'name': 'Maggie Haberman',
#    'id': 93069110,
#    'id_str': '93069110',
#    'indices': [0, 10]},
#   {'screen_name': 'MarkMeadows',
#    'name': 'Mark Meadows',
#    'id': 963480595,
#    'id_str': '963480595',
#    'indices': [230, 242]}],
#  [],
#  [],
#  [],
#  [],
#  [{'screen_name': 'BreitbartNews',
#    'name': 'Breitbart News',
#    'id': 457984599,
#    'id_str': '457984599',
#    'indices': [101, 115]}],
#  [{'screen_name': 'marklevinshow',
#    'name': 'Mark R. Levin',
#    'id': 38495835,
#    'id_str': '38495835',
#    'indices': [10, 24]},
#   {'screen_name': 'FoxNews',
#    'name': 'Fox News',
#    'id': 1367531,
#    'id_str': '1367531',
#    'indices': [28, 36]},
#   {'screen_name': 'SteveHiltonx',
#    'name': 'steve hilton',
#    'id': 2779389582,
#    'id_str': '2779389582',
#    'indices': [117, 130]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'screen_name': 'FoxNews',
#    'name': 'Fox News',
#    'id': 1367531,
#    'id_str': '1367531',
#    'indices': [20, 28]},
#   {'screen_name': 'marklevinshow',
#    'name': 'Mark R. Levin',
#    'id': 38495835,
#    'id_str': '38495835',
#    'indices': [30, 44]},
#   {'screen_name': 'NextRevFNC',
#    'name': 'The Next Revolution',
#    'id': 851526166100029442,
#    'id_str': '851526166100029442',
#    'indices': [124, 135]},
#   {'screen_name': 'SteveHiltonx',
#    'name': 'steve hilton',
#    'id': 2779389582,
#    'id_str': '2779389582',
#    'indices': [141, 154]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'screen_name': 'nypost',
#    'name': 'New York Post',
#    'id': 17469289,
#    'id_str': '17469289',
#    'indices': [18, 25]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'screen_name': 'BreitbartNews',
#    'name': 'Breitbart News',
#    'id': 457984599,
#    'id_str': '457984599',
#    'indices': [98, 112]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'screen_name': 'BreitbartNews',
#    'name': 'Breitbart News',
#    'id': 457984599,
#    'id_str': '457984599',
#    'indices': [97, 111]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'screen_name': 'SenSasse',
#    'name': 'Senator Ben Sasse',
#    'id': 2962923040,
#    'id_str': '2962923040',
#    'indices': [181, 190]}],
#  [],
#  [],
#  [{'screen_name': 'SenSasse',
#    'name': 'Senator Ben Sasse',
#    'id': 2962923040,
#    'id_str': '2962923040',
#    'indices': [197, 206]}],
#  [{'screen_name': 'BreitbartNews',
#    'name': 'Breitbart News',
#    'id': 457984599,
#    'id_str': '457984599',
#    'indices': [93, 107]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'screen_name': 'SenatorCollins',
#    'name': 'Sen. Susan Collins',
#    'id': 19726613,
#    'id_str': '19726613',
#    'indices': [38, 53]}],
#  [],
#  [{'screen_name': 'cspan',
#    'name': 'CSPAN',
#    'id': 15675138,
#    'id_str': '15675138',
#    'indices': [16, 22]}],
#  [{'screen_name': 'NBCNews',
#    'name': 'NBC News',
#    'id': 14173315,
#    'id_str': '14173315',
#    'indices': [34, 42]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'screen_name': 'GStephanopoulos',
#    'name': 'GeorgeStephanopoulos',
#    'id': 17074440,
#    'id_str': '17074440',
#    'indices': [74, 90]}],
#  [],
#  [],
#  [],
#  [],
#  [{'screen_name': 'TheBabylonBee',
#    'name': 'The Babylon Bee',
#    'id': 4914384040,
#    'id_str': '4914384040',
#    'indices': [100, 114]}],
#  [],
#  [],
#  [{'screen_name': 'NBCNews',
#    'name': 'NBC News',
#    'id': 14173315,
#    'id_str': '14173315',
#    'indices': [29, 37]},
#   {'screen_name': 'cspan',
#    'name': 'CSPAN',
#    'id': 15675138,
#    'id_str': '15675138',
#    'indices': [178, 184]}],
#  [{'screen_name': 'cspan',
#    'name': 'CSPAN',
#    'id': 15675138,
#    'id_str': '15675138',
#    'indices': [136, 142]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'screen_name': 'Varneyco',
#    'name': 'Varney & Co.',
#    'id': 281610530,
#    'id_str': '281610530',
#    'indices': [23, 32]},
#   {'screen_name': 'FoxBusiness',
#    'name': 'FOX Business',
#    'id': 56413858,
#    'id_str': '56413858',
#    'indices': [36, 48]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'screen_name': 'GamebredFighter',
#    'name': 'Jorge Masvidal UFC',
#    'id': 242960383,
#    'id_str': '242960383',
#    'indices': [82, 98]}],
#  [],
#  [],
#  [{'screen_name': 'nypost',
#    'name': 'New York Post',
#    'id': 17469289,
#    'id_str': '17469289',
#    'indices': [23, 30]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'screen_name': 'nypost',
#    'name': 'New York Post',
#    'id': 17469289,
#    'id_str': '17469289',
#    'indices': [138, 145]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'screen_name': 'OANN',
#    'name': 'One America News',
#    'id': 1209936918,
#    'id_str': '1209936918',
#    'indices': [6, 11]},
#   {'screen_name': 'newsmax',
#    'name': 'Newsmax',
#    'id': 20545835,
#    'id_str': '20545835',
#    'indices': [13, 21]},
#   {'screen_name': 'cspan',
#    'name': 'CSPAN',
#    'id': 15675138,
#    'id_str': '15675138',
#    'indices': [23, 29]}],
#  [],
#  [],
#  [],
#  [{'screen_name': 'CoryBooker',
#    'name': 'Cory Booker',
#    'id': 15808765,
#    'id_str': '15808765',
#    'indices': [57, 68]}],
#  [],
#  [{'screen_name': 'USNavy',
#    'name': 'U.S. Navy',
#    'id': 54885400,
#    'id_str': '54885400',
#    'indices': [34, 41]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'screen_name': 'OANN',
#    'name': 'One America News',
#    'id': 1209936918,
#    'id_str': '1209936918',
#    'indices': [168, 173]}],
#  [],
#  [{'screen_name': 'fema',
#    'name': 'FEMA',
#    'id': 16669075,
#    'id_str': '16669075',
#    'indices': [161, 166]},
#   {'screen_name': 'USArmy',
#    'name': 'U.S. Army',
#    'id': 8775672,
#    'id_str': '8775672',
#    'indices': [167, 174]}],
#  [],
#  [{'screen_name': 'WINRED',
#    'name': 'WinRed',
#    'id': 1121327121723527168,
#    'id_str': '1121327121723527168',
#    'indices': [42, 49]}],
#  [{'screen_name': 'GOPLeader',
#    'name': 'Kevin McCarthy',
#    'id': 19739126,
#    'id_str': '19739126',
#    'indices': [140, 150]}],
#  [{'screen_name': 'NBA',
#    'name': 'NBA',
#    'id': 19923144,
#    'id_str': '19923144',
#    'indices': [111, 115]},
#   {'screen_name': 'FoxNews',
#    'name': 'Fox News',
#    'id': 1367531,
#    'id_str': '1367531',
#    'indices': [232, 240]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'screen_name': 'BreitbartNews',
#    'name': 'Breitbart News',
#    'id': 457984599,
#    'id_str': '457984599',
#    'indices': [92, 106]}],
#  [],
#  [{'screen_name': 'BreitbartNews',
#    'name': 'Breitbart News',
#    'id': 457984599,
#    'id_str': '457984599',
#    'indices': [101, 115]}],
#  [{'screen_name': 'BreitbartNews',
#    'name': 'Breitbart News',
#    'id': 457984599,
#    'id_str': '457984599',
#    'indices': [120, 134]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'screen_name': 'OANN',
#    'name': 'One America News',
#    'id': 1209936918,
#    'id_str': '1209936918',
#    'indices': [71, 76]},
#   {'screen_name': 'cspan',
#    'name': 'CSPAN',
#    'id': 15675138,
#    'id_str': '15675138',
#    'indices': [78, 84]},
#   {'screen_name': 'newsmax',
#    'name': 'Newsmax',
#    'id': 20545835,
#    'id_str': '20545835',
#    'indices': [86, 94]}],
#  [{'screen_name': 'FoxNews',
#    'name': 'Fox News',
#    'id': 1367531,
#    'id_str': '1367531',
#    'indices': [1, 9]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'screen_name': 'BreitbartNews',
#    'name': 'Breitbart News',
#    'id': 457984599,
#    'id_str': '457984599',
#    'indices': [108, 122]}],
#  [],
#  [],
#  [{'screen_name': 'BreitbartNews',
#    'name': 'Breitbart News',
#    'id': 457984599,
#    'id_str': '457984599',
#    'indices': [123, 137]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'screen_name': 'OANN',
#    'name': 'One America News',
#    'id': 1209936918,
#    'id_str': '1209936918',
#    'indices': [70, 75]},
#   {'screen_name': 'newsmax',
#    'name': 'Newsmax',
#    'id': 20545835,
#    'id_str': '20545835',
#    'indices': [77, 85]},
#   {'screen_name': 'cspan',
#    'name': 'CSPAN',
#    'id': 15675138,
#    'id_str': '15675138',
#    'indices': [90, 96]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'screen_name': 'CNN',
#    'name': 'CNN',
#    'id': 759251,
#    'id_str': '759251',
#    'indices': [15, 19]},
#   {'screen_name': 'nytimes',
#    'name': 'The New York Times',
#    'id': 807095,
#    'id_str': '807095',
#    'indices': [40, 48]}],
#  [],
#  [],
#  [],
#  [{'screen_name': 'FoxNews',
#    'name': 'Fox News',
#    'id': 1367531,
#    'id_str': '1367531',
#    'indices': [39, 47]}],
#  [],
#  [],
#  [],
#  [],
#  [{'screen_name': 'NateSilver538',
#    'name': 'Nate Silver',
#    'id': 16017475,
#    'id_str': '16017475',
#    'indices': [1, 15]}],
#  [{'screen_name': 'JudgeJeanine',
#    'name': 'Jeanine Pirro',
#    'id': 29458079,
#    'id_str': '29458079',
#    'indices': [114, 127]},
#   {'screen_name': 'tedcruz',
#    'name': 'Ted Cruz',
#    'id': 23022687,
#    'id_str': '23022687',
#    'indices': [128, 136]}],
#  [],
#  [],
#  [],
#  [{'screen_name': 'stephaniebice',
#    'name': 'Stephanie Bice',
#    'id': 32289500,
#    'id_str': '32289500',
#    'indices': [18, 32]}],
#  [{'screen_name': 'Yvette4congress',
#    'name': 'Yvette Herrell',
#    'id': 898787903609765890,
#    'id_str': '898787903609765890',
#    'indices': [16, 32]}],
#  [{'screen_name': 'NancyMace',
#    'name': 'Nancy Mace',
#    'id': 914815520842616834,
#    'id_str': '914815520842616834',
#    'indices': [8, 18]}],
#  [{'screen_name': 'Tiffany_Shedd',
#    'name': 'Tiffany Shedd',
#    'id': 871768526620700673,
#    'id_str': '871768526620700673',
#    'indices': [23, 37]}],
#  [{'screen_name': 'DaleCraftsME',
#    'name': 'Dale Crafts',
#    'id': 1179018323935334400,
#    'id_str': '1179018323935334400',
#    'indices': [13, 26]}],
#  [{'screen_name': 'hinsonashley',
#    'name': 'Ashley Hinson',
#    'id': 18189966,
#    'id_str': '18189966',
#    'indices': [15, 28]}],
#  [],
#  [],
#  [{'screen_name': 'AlvaroUribeVel',
#    'name': 'Álvaro Uribe Vélez',
#    'id': 61097151,
#    'id_str': '61097151',
#    'indices': [36, 51]}],
#  [{'screen_name': 'FloridaChiefs',
#    'name': 'Florida Police Chiefs Association',
#    'id': 1013850028400631809,
#    'id_str': '1013850028400631809',
#    'indices': [147, 161]}],
#  [{'screen_name': 'EveningEdit',
#    'name': 'The Evening Edit',
#    'id': 2375568110,
#    'id_str': '2375568110',
#    'indices': [51, 63]},
#   {'screen_name': 'FoxNews',
#    'name': 'Fox News',
#    'id': 1367531,
#    'id_str': '1367531',
#    'indices': [64, 72]}],
#  [{'screen_name': 'SteveScully',
#    'name': 'Steve Scully',
#    'id': 24926288,
#    'id_str': '24926288',
#    'indices': [1, 13]}],
#  [{'screen_name': 'SenatorDole',
#    'name': 'Senator Bob Dole',
#    'id': 3342812001,
#    'id_str': '3342812001',
#    'indices': [10, 22]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'screen_name': 'RushLimbaughEIB',
#    'name': 'Rush Limbaugh',
#    'id': 171658945,
#    'id_str': '171658945',
#    'indices': [24, 40]}],
#  [],
#  [{'screen_name': 'fema',
#    'name': 'FEMA',
#    'id': 16669075,
#    'id_str': '16669075',
#    'indices': [81, 86]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'screen_name': 'seanhannity',
#    'name': 'Sean Hannity',
#    'id': 41634520,
#    'id_str': '41634520',
#    'indices': [25, 37]},
#   {'screen_name': 'FoxNews',
#    'name': 'Fox News',
#    'id': 1367531,
#    'id_str': '1367531',
#    'indices': [59, 67]}],
#  [{'screen_name': 'wandavazquezg',
#    'name': 'Wanda Vázquez Garced',
#    'id': 822185179477315584,
#    'id_str': '822185179477315584',
#    'indices': [262, 276]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'screen_name': 'MariaBartiromo',
#    'name': 'Maria Bartiromo',
#    'id': 208155240,
#    'id_str': '208155240',
#    'indices': [23, 38]},
#   {'screen_name': 'FoxBusiness',
#    'name': 'FOX Business',
#    'id': 56413858,
#    'id_str': '56413858',
#    'indices': [53, 65]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'screen_name': 'VP',
#    'name': 'Vice President Mike Pence',
#    'id': 818910970567344128,
#    'id_str': '818910970567344128',
#    'indices': [18, 21]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'screen_name': 'BorisJohnson',
#    'name': 'Boris Johnson',
#    'id': 3131144855,
#    'id_str': '3131144855',
#    'indices': [31, 44]}],
#  [{'screen_name': 'GovAbbott',
#    'name': 'Gov. Greg Abbott',
#    'id': 19291441,
#    'id_str': '19291441',
#    'indices': [52, 62]},
#   {'screen_name': 'LouisianaGov',
#    'name': 'John Bel Edwards',
#    'id': 166374616,
#    'id_str': '166374616',
#    'indices': [76, 89]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'screen_name': 'SpeakerPelosi',
#    'name': 'Nancy Pelosi',
#    'id': 15764644,
#    'id_str': '15764644',
#    'indices': [33, 47]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'screen_name': 'BreitbartNews',
#    'name': 'Breitbart News',
#    'id': 457984599,
#    'id_str': '457984599',
#    'indices': [137, 151]}],
#  [],
#  [{'screen_name': 'MarshaBlackburn',
#    'name': 'Sen. Marsha Blackburn',
#    'id': 278145569,
#    'id_str': '278145569',
#    'indices': [206, 222]}],
#  [{'screen_name': 'MarkMeadows',
#    'name': 'Mark Meadows',
#    'id': 963480595,
#    'id_str': '963480595',
#    'indices': [167, 179]},
#   {'screen_name': 'senatemajldr',
#    'name': 'Leader McConnell',
#    'id': 1249982359,
#    'id_str': '1249982359',
#    'indices': [180, 193]},
#   {'screen_name': 'kevinomccarthy',
#    'name': 'Kevin McCarthy',
#    'id': 15428227,
#    'id_str': '15428227',
#    'indices': [194, 209]},
#   {'screen_name': 'SpeakerPelosi',
#    'name': 'Nancy Pelosi',
#    'id': 15764644,
#    'id_str': '15764644',
#    'indices': [210, 224]},
#   {'screen_name': 'SenSchumer',
#    'name': 'Chuck Schumer',
#    'id': 17494010,
#    'id_str': '17494010',
#    'indices': [225, 236]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'screen_name': 'SteveFDA',
#    'name': 'Dr. Stephen M. Hahn',
#    'id': 2904169317,
#    'id_str': '2904169317',
#    'indices': [133, 142]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'screen_name': 'SenatorWicker',
#    'name': 'Senator Roger Wicker',
#    'id': 264219447,
#    'id_str': '264219447',
#    'indices': [74, 88]}],
#  [],
#  [],
#  [],
#  [],
#  [{'screen_name': 'senatemajldr',
#    'name': 'Leader McConnell',
#    'id': 1249982359,
#    'id_str': '1249982359',
#    'indices': [3, 16]}],
#  [],
#  [],
#  [{'screen_name': 'NBCNews',
#    'name': 'NBC News',
#    'id': 14173315,
#    'id_str': '14173315',
#    'indices': [100, 108]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'screen_name': 'mirandadevine',
#    'name': 'Miranda Devine',
#    'id': 32201297,
#    'id_str': '32201297',
#    'indices': [174, 188]},
#   {'screen_name': 'nypost',
#    'name': 'New York Post',
#    'id': 17469289,
#    'id_str': '17469289',
#    'indices': [189, 196]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [{'screen_name': 'BreitbartNews',
#    'name': 'Breitbart News',
#    'id': 457984599,
#    'id_str': '457984599',
#    'indices': [137, 151]}],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ...]

# %%
type(name)
# Out:
# list

# %%
name[3]
# Out:
# [{'screen_name': 'BreitbartNews',
#   'name': 'Breitbart News',
#   'id': 457984599,
#   'id_str': '457984599',
#   'indices': [98, 112]}]

# %%
df['name2']= [x[] for x in name]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-212-2fb58959bb96> in <module>
# ----> 1 df['name2']=[x for x in df['name'][0]]
#
# ~\anaconda3\envs\ace592\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3038         else:
#    3039             # set column
# -> 3040             self._set_item(key, value)
#    3041
#    3042     def _setitem_slice(self, key: slice, value):
#
# ~\anaconda3\envs\ace592\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3114         """
#    3115         self._ensure_valid_index(value)
# -> 3116         value = self._sanitize_column(key, value)
#    3117         NDFrame._set_item(self, key, value)
#    3118
#
# ~\anaconda3\envs\ace592\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3762
#    3763             # turn me into an ndarray
# -> 3764             value = sanitize_index(value, self.index)
#    3765             if not isinstance(value, (np.ndarray, Index)):
#    3766                 if isinstance(value, list) and len(value) > 0:
#
# ~\anaconda3\envs\ace592\lib\site-packages\pandas\core\internals\construction.py in sanitize_index(data, index)
#     745     """
#     746     if len(data) != len(index):
# --> 747         raise ValueError(
#     748             "Length of values "
#     749             f"({len(data)}) "
#
# ValueError: Length of values (1) does not match length of index (3018)
